# %% [markdown]
# <a href="https://colab.research.google.com/github/kuo-yu-chen/fin-data/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/kuo-yu-chen/fin-data/refs/heads/main/1217.csv"

# %%
df1 = pd.read_csv (url, index_col=0, encoding='unicode_escape')

# %%
df1
# Out:
#           YYYY/MM  Quarter consolidation  Month Currency  \
# ï»¿CO_ID
# 1101 TCC  2023/12        4             Y     12      NTD
# 1102 ACC  2023/12        4             Y     12      NTD
#
#          Total cash and cash equivalents  \
# ï»¿CO_ID
# 1101 TCC                      66,366,622
# 1102 ACC                      33,229,516
#
#          Total current financial assets at fair value through profit or loss  \
# ï»¿CO_ID
# 1101 TCC                                            727,762
# 1102 ACC                                         39,719,980
#
#          Financial assets at fair value through other comprehensive income - Current  \
# ï»¿CO_ID
# 1101 TCC                                          6,972,790
# 1102 ACC                                          4,307,126
#
#          Financial assets measured at amortized cost - Current  \
# ï»¿CO_ID
# 1101 TCC                                         34,236,957
# 1102 ACC                                         21,684,983
#
#           Current financial assets for hedging  ...  \
# ï»¿CO_ID                                        ...
# 1101 TCC                                     0  ...
# 1102 ACC                                     0  ...
#
#          Other equity - unearned compensation Other equity, others  \
# ï»¿CO_ID
# 1101 TCC                                    0                    0
# 1102 ACC                                    0                    0
#
#          Total other equity interest  Treasury shares  \
# ï»¿CO_ID
# 1101 TCC                   9,457,953         -732,459
# 1102 ACC                   7,219,740                0
#
#          Total equity attributable to owners of parent  \
# ï»¿CO_ID
# 1101 TCC                                   230,933,254
# 1102 ACC                                   169,169,896
#
#           Interests in the former associate or jointly controlled entity  \
# ï»¿CO_ID
# 1101 TCC                                                  0
# 1102 ACC                                                  0
#
#          Non-controlling interest in pre-acquisition share capital  \
# ï»¿CO_ID
# 1101 TCC                                                  0
# 1102 ACC                                                  0
#
#           Non-controlling interests Total equity Total liabilities & equity
# ï»¿CO_ID
# 1101 TCC                 22,967,787  253,901,041                469,438,522
# 1102 ACC                 22,693,671  191,863,567                336,726,851
#
# [2 rows x 111 columns]

# %%
url = "https://raw.githubusercontent.com/kuo-yu-chen/fin-data/refs/heads/main/1217.csv"

# %%
df2 = pd.read_csv (url, index_col=0, encoding='unicode_escape')

# %%
df2
# Out:
#           YYYY/MM  Quarter consolidation  Month Currency  \
# ï»¿CO_ID
# 1101 TCC  2023/12        4             Y     12      NTD
# 1102 ACC  2023/12        4             Y     12      NTD
#
#          Total cash and cash equivalents  \
# ï»¿CO_ID
# 1101 TCC                      66,366,622
# 1102 ACC                      33,229,516
#
#          Total current financial assets at fair value through profit or loss  \
# ï»¿CO_ID
# 1101 TCC                                            727,762
# 1102 ACC                                         39,719,980
#
#          Financial assets at fair value through other comprehensive income - Current  \
# ï»¿CO_ID
# 1101 TCC                                          6,972,790
# 1102 ACC                                          4,307,126
#
#          Financial assets measured at amortized cost - Current  \
# ï»¿CO_ID
# 1101 TCC                                         34,236,957
# 1102 ACC                                         21,684,983
#
#           Current financial assets for hedging  ...  \
# ï»¿CO_ID                                        ...
# 1101 TCC                                     0  ...
# 1102 ACC                                     0  ...
#
#          Other equity - unearned compensation Other equity, others  \
# ï»¿CO_ID
# 1101 TCC                                    0                    0
# 1102 ACC                                    0                    0
#
#          Total other equity interest  Treasury shares  \
# ï»¿CO_ID
# 1101 TCC                   9,457,953         -732,459
# 1102 ACC                   7,219,740                0
#
#          Total equity attributable to owners of parent  \
# ï»¿CO_ID
# 1101 TCC                                   230,933,254
# 1102 ACC                                   169,169,896
#
#           Interests in the former associate or jointly controlled entity  \
# ï»¿CO_ID
# 1101 TCC                                                  0
# 1102 ACC                                                  0
#
#          Non-controlling interest in pre-acquisition share capital  \
# ï»¿CO_ID
# 1101 TCC                                                  0
# 1102 ACC                                                  0
#
#           Non-controlling interests Total equity Total liabilities & equity
# ï»¿CO_ID
# 1101 TCC                 22,967,787  253,901,041                469,438,522
# 1102 ACC                 22,693,671  191,863,567                336,726,851
#
# [2 rows x 111 columns]

# %%
A_1101 = (df1.loc['1101 TCC','Total current assets'] - (df1.loc['1101 TCC','Total current liabilities']))/(df1.loc['1101 TCC','Total assets('])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-338428287673> in <cell line: 1>()
# ----> 1 A_1101 = (df1.loc['1101 TCC','Total current assets'] - (df1.loc['1101 TCC','Total current liabilities']))/(df1.loc['1101 TCC','Total assets('])
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
from os import X_OK
X1 = 'Total current assets'
X2 = 'Total current liabilities'
X3 = 'Total assets'
X4 = 'Total retained earnings'
X5 = 'Earnings before interest and tax'
X6 = 'Total equity'
X7 = 'Total operating revenue'
TCC ='1101 TCC'
ACC ='1102 ACC'
